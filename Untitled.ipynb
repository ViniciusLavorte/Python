# %%
import pandas as pd
from itertools import combinations
from itertools import permutations

# %%
mes = ["JAN","FEV","MAR","ABR","MAI","JUN","JUL","AGO","SET","OUT","NOV","DEZ"]
mes
# Out:
# ['JAN',
#  'FEV',
#  'MAR',
#  'ABR',
#  'MAI',
#  'JUN',
#  'JUL',
#  'AGO',
#  'SET',
#  'OUT',
#  'NOV',
#  'DEZ']

# %%
mes_1 = []
mes_2 = []
for d in mes:
    mes_1.append(d + '1')
    mes_2.append(d + '2')
mes_1
mes_2
# Out:
# ['JAN2',
#  'FEV2',
#  'MAR2',
#  'ABR2',
#  'MAI2',
#  'JUN2',
#  'JUL2',
#  'AGO2',
#  'SET2',
#  'OUT2',
#  'NOV2',
#  'DEZ2']

# %%
meses = mes_1 + mes_2
meses
# Out:
# ['JAN1',
#  'FEV1',
#  'MAR1',
#  'ABR1',
#  'MAI1',
#  'JUN1',
#  'JUL1',
#  'AGO1',
#  'SET1',
#  'OUT1',
#  'NOV1',
#  'DEZ1',
#  'JAN2',
#  'FEV2',
#  'MAR2',
#  'ABR2',
#  'MAI2',
#  'JUN2',
#  'JUL2',
#  'AGO2',
#  'SET2',
#  'OUT2',
#  'NOV2',
#  'DEZ2']

# %%
#for a in combinations(meses, 2):
#    print(a)
list(combinations(meses,2))
# Out:
# [('JAN1', 'FEV1'),
#  ('JAN1', 'MAR1'),
#  ('JAN1', 'ABR1'),
#  ('JAN1', 'MAI1'),
#  ('JAN1', 'JUN1'),
#  ('JAN1', 'JUL1'),
#  ('JAN1', 'AGO1'),
#  ('JAN1', 'SET1'),
#  ('JAN1', 'OUT1'),
#  ('JAN1', 'NOV1'),
#  ('JAN1', 'DEZ1'),
#  ('JAN1', 'JAN2'),
#  ('JAN1', 'FEV2'),
#  ('JAN1', 'MAR2'),
#  ('JAN1', 'ABR2'),
#  ('JAN1', 'MAI2'),
#  ('JAN1', 'JUN2'),
#  ('JAN1', 'JUL2'),
#  ('JAN1', 'AGO2'),
#  ('JAN1', 'SET2'),
#  ('JAN1', 'OUT2'),
#  ('JAN1', 'NOV2'),
#  ('JAN1', 'DEZ2'),
#  ('FEV1', 'MAR1'),
#  ('FEV1', 'ABR1'),
#  ('FEV1', 'MAI1'),
#  ('FEV1', 'JUN1'),
#  ('FEV1', 'JUL1'),
#  ('FEV1', 'AGO1'),
#  ('FEV1', 'SET1'),
#  ('FEV1', 'OUT1'),
#  ('FEV1', 'NOV1'),
#  ('FEV1', 'DEZ1'),
#  ('FEV1', 'JAN2'),
#  ('FEV1', 'FEV2'),
#  ('FEV1', 'MAR2'),
#  ('FEV1', 'ABR2'),
#  ('FEV1', 'MAI2'),
#  ('FEV1', 'JUN2'),
#  ('FEV1', 'JUL2'),
#  ('FEV1', 'AGO2'),
#  ('FEV1', 'SET2'),
#  ('FEV1', 'OUT2'),
#  ('FEV1', 'NOV2'),
#  ('FEV1', 'DEZ2'),
#  ('MAR1', 'ABR1'),
#  ('MAR1', 'MAI1'),
# ...

# %%
list2 = [1, 2]

all_combinations = [list(zip(each_permutation, list2)) for each_permutation in permutations(mes, len(list2))]
list(all_combinations)
# Out:
# [[('JAN', 1), ('FEV', 2)],
#  [('JAN', 1), ('MAR', 2)],
#  [('JAN', 1), ('ABR', 2)],
#  [('JAN', 1), ('MAI', 2)],
#  [('JAN', 1), ('JUN', 2)],
#  [('JAN', 1), ('JUL', 2)],
#  [('JAN', 1), ('AGO', 2)],
#  [('JAN', 1), ('SET', 2)],
#  [('JAN', 1), ('OUT', 2)],
#  [('JAN', 1), ('NOV', 2)],
#  [('JAN', 1), ('DEZ', 2)],
#  [('FEV', 1), ('JAN', 2)],
#  [('FEV', 1), ('MAR', 2)],
#  [('FEV', 1), ('ABR', 2)],
#  [('FEV', 1), ('MAI', 2)],
#  [('FEV', 1), ('JUN', 2)],
#  [('FEV', 1), ('JUL', 2)],
#  [('FEV', 1), ('AGO', 2)],
#  [('FEV', 1), ('SET', 2)],
#  [('FEV', 1), ('OUT', 2)],
#  [('FEV', 1), ('NOV', 2)],
#  [('FEV', 1), ('DEZ', 2)],
#  [('MAR', 1), ('JAN', 2)],
#  [('MAR', 1), ('FEV', 2)],
#  [('MAR', 1), ('ABR', 2)],
#  [('MAR', 1), ('MAI', 2)],
#  [('MAR', 1), ('JUN', 2)],
#  [('MAR', 1), ('JUL', 2)],
#  [('MAR', 1), ('AGO', 2)],
#  [('MAR', 1), ('SET', 2)],
#  [('MAR', 1), ('OUT', 2)],
#  [('MAR', 1), ('NOV', 2)],
#  [('MAR', 1), ('DEZ', 2)],
#  [('ABR', 1), ('JAN', 2)],
# ...
