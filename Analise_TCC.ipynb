# %%
import numpy as np
import pandas as pd
import sqlalchemy as sqla
import matplotlib.pyplot as plt
base = pd.read_csv('Resultados_TCC2 - eval.csv')

# %%
base.head()
# Out:
#                              Pasta Amostra_Dados          Rede  Precisao_1  \
# 0               inceptionv3_larvae        larvae  Inception_v3      0.8974
# 1               inceptionv3_cevada        cevada  Inception_v3      0.6250
# 2             inceptionv3_mammoset      mammoset  Inception_v3      0.4271
# 3  inceptionv3_larvae_augmentation        larvae  Inception_v3      0.8397
# 4  inceptionv3_cevada_augmentation        cevada  Inception_v3      0.6875
#
#    Tempo_1  Precisao_2  Tempo_2  Precisao_3  Tempo_3  Precisao_4  ...  \
# 0    21.46      0.8972    44.15      0.9055    66.25      0.9017  ...
# 1     3.38      0.7500   127.12      0.7344   164.78      0.7159  ...
# 2    45.80      0.4362   187.15      0.4329   268.36      0.4349  ...
# 3    23.86      0.8449   114.28      0.8351   181.97      0.8333  ...
# 4     5.35      0.6500    50.98      0.5938    96.88      0.5455  ...
#
#    Precisao_5  Tempo_5  Precisao_6  Tempo_6  Precisao_7  Tempo_7  Precisao_8  \
# 0      0.8990   111.02         NaN      NaN         NaN      NaN         NaN
# 1      0.7212   261.87         NaN      NaN         NaN      NaN         NaN
# 2      0.4349   432.62         NaN      NaN         NaN      NaN         NaN
# 3      0.8314   291.33         NaN      NaN         NaN      NaN         NaN
# 4      0.5385   175.39         NaN      NaN         NaN      NaN         NaN
#
#    Tempo_8  Precisao_final  Tempo_final
# 0      NaN          0.8976       112.28
# 1      NaN          0.7250       294.95
# 2      NaN          0.4342       462.21
# 3      NaN          0.8313       320.98
# 4      NaN          0.5417       208.35
#
# [5 rows x 21 columns]

# %%
base.columns
# Out:
# Index([u'Pasta', u'Amostra_Dados', u'Rede', u'Precisao_1', u'Tempo_1',
#        u'Precisao_2', u'Tempo_2', u'Precisao_3', u'Tempo_3', u'Precisao_4',
#        u'Tempo_4', u'Precisao_5', u'Tempo_5', u'Precisao_6', u'Tempo_6',
#        u'Precisao_7', u'Tempo_7', u'Precisao_8', u'Tempo_8', u'Precisao_final',
#        u'Tempo_final'],
#       dtype='object')

# %%
Precisao = ['Pasta','Precisao_1','Precisao_2','Precisao_3','Precisao_4','Precisao_5','Precisao_6','Precisao_7','Precisao_8', 'Precisao_final']
Tempo = ['Pasta','Tempo_1','Tempo_2','Tempo_3','Tempo_4','Tempo_5','Tempo_6','Tempo_7','Tempo_8','Tempo_final']

# %% [markdown]
# ## Inception_v3 and Larvae

# %%
# Precisão Inception_v3 e Larvae
b = base.loc[(base.Amostra_Dados == 'larvae') & (base.Rede == 'Inception_v3'),Precisao]
bt = b.T
bt.columns = bt.iloc[0]
bt = bt.drop(['Pasta'])
bt_row = ['P1','P2','P3','P4','P5','P6','P7','P8','P_Final']
bt.index = bt_row
#bt = bt.fillna(bt.iloc[1:,].mean())


# Tempo Inception_v3 e Larvae
c = base.loc[(base.Amostra_Dados == 'larvae') & (base.Rede == 'Inception_v3'),Tempo]
ct = c.T
ct.columns = ct.iloc[0]
ct = ct.drop(['Pasta'])
ct_row = ['T1','T2','T3','T4','T5','T6','T7','T8','T_Final']
ct.index =  ct_row
ct = ct.fillna(ct.iloc[-1,:])
ct
# Out:
# Pasta    inceptionv3_larvae  inceptionv3_larvae_augmentation  \
# T1                    21.46                            23.86
# T2                    44.15                           114.28
# T3                    66.25                           181.97
# T4                    89.03                           237.78
# T5                   111.02                           291.33
# T6                   112.28                           320.98
# T7                   112.28                           320.98
# T8                   112.28                           320.98
# T_Final              112.28                           320.98
#
# Pasta    inceptionv3_larvae_param_Alto  inceptionv3_larvae_param_Baixo
# T1                               20.48                           24.48
# T2                               43.46                           49.16
# T3                               64.86                           73.32
# T4                               86.22                           74.05
# T5                              107.64                           74.05
# T6                              129.06                           74.05
# T7                              150.50                           74.05
# T8                              171.27                           74.05
# T_Final                         172.69                           74.05

# %% [markdown]
# ## Plotando Inception_v3 and Larvae

# %%
# Plotando as saídas de Accuracia e tempo
#plt.figure(figsize=(9, 3))

plt.plot(bt.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Inception_v3 - Larvae')
plt.legend(bt.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()


plt.plot(ct.iloc[:-1,:],marker ='o')
plt.title('Tempo: Inception_v3 - Larvae')
plt.legend(bt.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Tempo')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ## Inception_v3 and Cevada

# %%
# Precisão Inception_v3 e Cevada
b = base.loc[(base.Amostra_Dados == 'cevada') & (base.Rede == 'Inception_v3'),Precisao]
bt = b.T
bt.columns = bt.iloc[0]
bt = bt.drop(['Pasta'])
bt_row = ['P1','P2','P3','P4','P5','P6','P7','P8','P_Final']
bt.index = bt_row
#bt = bt.fillna(bt.iloc[1:,].mean())


# Tempo Inception_v3 e Cevada
c = base.loc[(base.Amostra_Dados == 'cevada') & (base.Rede == 'Inception_v3'),Tempo]
ct = c.T
ct.columns = ct.iloc[0]
ct = ct.drop(['Pasta'])
ct_row = ['T1','T2','T3','T4','T5','T6','T7','T8','T_Final']
ct.index =  ct_row
ct = ct.fillna(ct.iloc[-1,:])
ct
# Out:
# Pasta    inceptionv3_cevada  inceptionv3_cevada_augmentation  \
# T1                     3.38                             5.35
# T2                   127.12                            50.98
# T3                   164.78                            96.88
# T4                   218.07                           140.16
# T5                   261.87                           175.39
# T6                   294.95                           208.35
# T7                   294.95                           208.35
# T8                   294.95                           208.35
# T_Final              294.95                           208.35
#
# Pasta    inceptionv3_cevada_param_Alto  inceptionv3_cevada_param_Baixo
# T1                                4.28                            5.63
# T2                                6.46                           10.91
# T3                                8.62                           12.99
# T4                               11.09                           13.93
# T5                               13.26                           13.93
# T6                               15.82                           13.93
# T7                               18.28                           13.93
# T8                               19.82                           13.93
# T_Final                          21.56                           13.93

# %% [markdown]
# ## Plotting Inception_v3 and Cevada

# %%
# Plotando as saídas de Accuracia e tempo
plt.plot(bt.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Inception_v3 - Cevada')
plt.legend(bt.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(ct.iloc[:-1,:],marker ='o')
plt.title('Tempo: Inception_v3 - Cevada')
plt.legend(bt.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Tempo')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ## Inception_v3 and Mammoset

# %%
# Precisão Inception_v3 e Mammoset
b = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Rede == 'Inception_v3'),Precisao]
bt = b.T
bt.columns = bt.iloc[0]
bt = bt.drop(['Pasta'])
bt_row = ['P1','P2','P3','P4','P5','P6','P7','P8','P_Final']
bt.index = bt_row
#bt = bt.fillna(bt.iloc[1:,].mean())


# Tempo Inception_v3 e Mammoset
c = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Rede == 'Inception_v3'),Tempo]
ct = c.T
ct.columns = ct.iloc[0]
ct = ct.drop(['Pasta'])
ct_row = ['T1','T2','T3','T4','T5','T6','T7','T8','T_Final']
ct.index =  ct_row
ct = ct.fillna(ct.iloc[-1,:])
ct
# Out:
# Pasta    inceptionv3_mammoset  inceptionv3_mammoset_augmentation  \
# T1                      45.80                              47.19
# T2                     187.15                             148.66
# T3                     268.36                             229.22
# T4                     432.62                             310.38
# T5                     432.62                             395.06
# T6                     462.21                             437.15
# T7                     462.21                             437.15
# T8                     462.21                             437.15
# T_Final                462.21                             437.15
#
# Pasta    inceptionv3_mammoset_param_Alto  inceptionv3_mammoset_param_Baixo
# T1                                 43.50                             49.21
# T2                                 88.03                             98.72
# T3                                132.11                            147.66
# T4                                176.35                            148.64
# T5                                220.48                            148.64
# T6                                264.82                            148.64
# T7                                309.05                            148.64
# T8                                352.59                            148.64
# T_Final                           354.42                            148.64

# %% [markdown]
# ## Plotting Inception_v3 and Mammoset

# %%
# Plotando as saídas de Accuracia e tempo
plt.plot(bt.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Inception_v3 - Mammoset')
plt.legend(bt.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(ct.iloc[:-1,:],marker ='o')
plt.title('Tempo: Inception_v3 - Mammoset')
plt.legend(bt.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Tempo')
plt.xlabel('Epoch')
plt.show()
