# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
base = pd.read_csv('Resultados_TCC2 - eval.csv')

# %%
base.head()
# Out:
#                              Pasta Amostra_Dados          Tipo          Rede  \
# 0               inceptionv3_larvae        larvae        Normal  Inception_v3
# 1               inceptionv3_cevada        cevada        Normal  Inception_v3
# 2             inceptionv3_mammoset      mammoset        Normal  Inception_v3
# 3  inceptionv3_larvae_augmentation        larvae  Augmentation  Inception_v3
# 4  inceptionv3_cevada_augmentation        cevada  Augmentation  Inception_v3
#
#    Precisao_1  Tempo_1  Precisao_2  Tempo_2  Precisao_3  Tempo_3  ...  \
# 0      0.8974    21.46      0.8972    44.15      0.9055    66.25  ...
# 1      0.6250     3.38      0.7500   127.12      0.7344   164.78  ...
# 2      0.4271    45.80      0.4362   187.15      0.4329   268.36  ...
# 3      0.8397    23.86      0.8449   114.28      0.8351   181.97  ...
# 4      0.6875     5.35      0.6500    50.98      0.5938    96.88  ...
#
#    Precisao_5  Tempo_5  Precisao_6  Tempo_6  Precisao_7  Tempo_7  Precisao_8  \
# ...

# %%
Precisao = ['Rede','Precisao_1','Precisao_2','Precisao_3','Precisao_4','Precisao_5','Precisao_6','Precisao_7','Precisao_8', 'Precisao_final']
Tempo = ['Rede','Tempo_1','Tempo_2','Tempo_3','Tempo_4','Tempo_5','Tempo_6','Tempo_7','Tempo_8','Tempo_final']
bp = ['P1','P2','P3','P4','P5','P6','P7','P8','P_Final']

# %%
b = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Tipo == 'Normal'), Precisao]
b = b.T
b.columns = b.iloc[0,:]
b = b.drop(['Rede'])
b.index = bp

t = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Tipo == 'Normal'), Tempo]
t = t.T
t.columns = t.iloc[0,:]
t = t.drop(['Rede'])
t.index = bp

# %%
plt.plot(b.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Larvae Normal')
plt.legend(b.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(t.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Larvae Normal')
plt.legend(t.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
b = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Tipo == 'Augmentation'), Precisao]
b = b.T
b.columns = b.iloc[0,:]
b = b.drop(['Rede'])
b.index = bp

t = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Tipo == 'Augmentation'), Tempo]
t = t.T
t.columns = t.iloc[0,:]
t = t.drop(['Rede'])
t.index = bp

# %%
plt.plot(b.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Larvae Augmentation')
plt.legend(b.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(t.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Larvae Augmentation')
plt.legend(t.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
b = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Tipo == 'Alto'), Precisao]
b = b.T
b.columns = b.iloc[0,:]
b = b.drop(['Rede'])
b.index = bp

t = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Tipo == 'Alto'), Tempo]
t = t.T
t.columns = t.iloc[0,:]
t = t.drop(['Rede'])
t.index = bp

# %%
plt.plot(b.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Larvae Alto')
plt.legend(b.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(t.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Larvae Alto')
plt.legend(t.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
b = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Tipo == 'Baixo'), Precisao]
b = b.T
b.columns = b.iloc[0,:]
b = b.drop(['Rede'])
b.index = bp

t = base.loc[(base.Amostra_Dados == 'mammoset') & (base.Tipo == 'Baixo'), Tempo]
t = t.T
t.columns = t.iloc[0,:]
t = t.drop(['Rede'])
t.index = bp

# %%
plt.plot(b.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Larvae Baixo')
plt.legend(b.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(t.iloc[:-1,:],marker ='o')
plt.title('Accuracy: Larvae Baixo')
plt.legend(t.columns,loc='center left', bbox_to_anchor=(1, 0.7))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()
