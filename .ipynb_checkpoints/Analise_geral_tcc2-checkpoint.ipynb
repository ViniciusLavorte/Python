# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
base = pd.read_csv('Resultado_processado_TCC2_eval.csv',delimiter=';')

# %%
base.head()
# Out:
#                              Pasta Amostra_Dados          Rede  Precisao_1  \
# 0               inceptionv3_larvae        larvae  Inception_V3      0.8974
# 1               inceptionv3_cevada        cevada  Inception_V3      0.6250
# 2             inceptionv3_mammoset      mammoset  Inception_V3      0.4271
# 3  inceptionv3_larvae_augmentation        larvae  Inception_V3      0.8397
# 4  inceptionv3_cevada_augmentation        cevada  Inception_V3      0.6875
#
#    Tempo_1  Precisao_2  Tempo_2  Precisao_3  Tempo_3  Precisao_4     ...       \
# 0    21.46      0.8972    44.15      0.9055    66.25      0.9017     ...
# 1     3.38      0.7500   127.12      0.7344   164.78      0.7159     ...
# 2    45.80      0.4362   187.15      0.4329   268.36      0.4349     ...
# 3    23.86      0.8449   114.28      0.8351   181.97      0.8333     ...
# 4     5.35      0.6500    50.98      0.5938    96.88      0.5455     ...
#
#    Precisao_5  Tempo_5  Precisao_6  Tempo_6  Precisao_7  Tempo_7  Precisao_8  \
# 0      0.8990   111.02         NaN      NaN         NaN      NaN         NaN
# 1      0.7212   261.87         NaN      NaN         NaN      NaN         NaN
# 2      0.4349   432.62         NaN      NaN         NaN      NaN         NaN
# 3      0.8314   291.33         NaN      NaN         NaN      NaN         NaN
# 4      0.5385   175.39         NaN      NaN         NaN      NaN         NaN
#
#    Tempo_8  Precisao_final  Tempo_final
# 0      NaN          0.8976       112.28
# 1      NaN          0.7250       294.95
# 2      NaN          0.4342       462.21
# 3      NaN          0.8313       320.98
# 4      NaN          0.5417       208.35
#
# [5 rows x 21 columns]

# %%
Variavel_Normal = ['inceptionv3_larvae','resnetv2_larvae','nasnet_larvae']

# %%
a = map(lambda x: base.loc[base['Pasta'] == x,['Precisao_final','Tempo_final']] ,Variavel_Normal)

print(list(a))
#pd.DataFrame.from_dict(a)
# Out:
# [   Precisao_final  Tempo_final
# 0          0.8976       112.28,     Precisao_final  Tempo_final
# 10          0.8352       202.56,     Precisao_final  Tempo_final
# 16           0.952       651.18]

# %%
base[base['Pasta'] == 'inceptionv3_larvae']
# Out:
#                 Pasta Amostra_Dados          Rede  Precisao_1  Tempo_1  \
# 0  inceptionv3_larvae        larvae  Inception_V3      0.8974    21.46
#
#    Precisao_2  Tempo_2  Precisao_3  Tempo_3  Precisao_4     ...       \
# 0      0.8972    44.15      0.9055    66.25      0.9017     ...
#
#    Precisao_5  Tempo_5  Precisao_6  Tempo_6  Precisao_7  Tempo_7  Precisao_8  \
# 0       0.899   111.02         NaN      NaN         NaN      NaN         NaN
#
#    Tempo_8  Precisao_final  Tempo_final
# 0      NaN          0.8976       112.28
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Apresentando resultado para Arquitetura X Larvae

# %%
base.loc[((base['Pasta'] == 'nasnet_larvae')|(base['Pasta'] == 'inceptionv3_larvae') | (base['Pasta'] == 'resnetv2_larvae')),['Rede','Precisao_final','Tempo_final']].sort_values('Precisao_final',ascending=False)
# Out:
#             Rede  Precisao_final  Tempo_final
# 16        Nasnet          0.9520       651.18
# 0   Inception_V3          0.8976       112.28
# 10     Resnet_v2          0.8352       202.56

# %%
base.groupby(base['larvae']).mean()
# Out:
# -----------------------------------------------------------
# KeyError                  Traceback (most recent call last)
# ~/repositorios/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'larvae'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                  Traceback (most recent call last)
# <ipython-input-42-610168799e57> in <module>
# ----> 1 base.groupby(base['larvae']).mean()
#
# ~/repositorios/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/repositorios/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/repositorios/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/repositorios/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/repositorios/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'larvae'
